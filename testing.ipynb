# %%
from linkedin_api.client import LinkedInClient
from linkedin_api.profile import fetch_above_activity


client = LinkedInClient(
    li_at="YOUR_LI_AT",
    jsessionid="ajax:YOUR_JSESSIONID",
)

raw = fetch_above_activity(
    client,
    "prerona-basak",
)

print(raw)
# Out:
# 1:I["030d6035cb3a997efb1cff7a008d2f89",[],"default"]
# 3:I["e9e5744c902fddb98f0eb62aee5d400a",[],"TracedComponent"]
# 4:I["f54a4d9f94904eb227a6c1307124edd6",[],"ClientComponent"]
# 5:I["621c913cba38dd3c27c9f4d2692a01a9",[],"ReplaceableComponent"]
# 0:["$","div",null,{"data-sdui-component":"com.linkedin.sdui.generated.profile.dsl.impl.profileCardsAboveActivity","children":[false,[[["$","$L1",null,{"modelStates":[{"key":{"key":{"value":{"$case":"id","id":"prerona-basakAboutProfileComponentState"}}},"value":{"$case":"booleanValue","booleanValue":false}}]}],"$undefined"],"$L2",["$","div",null,{"className":"aa13b50b _01e54e47 _0e9ecad1 c227fcfa debf804b _258b0d42 _8ee9e85d _350a8c37","children":[["$","$L3",null,{"observabilityIdentifier":"com.linkedin.sdui.impl.profile.components.salesInsightOrHighlightsSection","children":["$","$L4",null,{"componentKey":"com.linkedin.sdui.profile.card.refACoAACG3cA4BQD1WaaIemI6YTNJoCmfQrjOJD8ASalesInsightsOrHighlights","children":["$","$L5","com.linkedin.sdui.profile.card.refACoAACG3cA4BQD1WaaIemI6YTNJoCmfQrjOJD8ASalesInsightsOrHighlights",{"componentKey":"com.linkedin.sdui.profile.card.refACoAACG3cA4BQD1WaaIemI6YTNJoCmfQrjOJD8ASalesInsightsOrHighlights","initialContent":"$undefined","componentkey":"com.linkedin.sdui.profile.card.refACoAACG3cA4BQD1WaaIemI6YTNJoCmfQrjOJD8ASalesInsightsOrHighlights","renderWithoutWrapper":false}]}]}],["$","$L3",null,{"observabilityIdentifier":"com.linkedin.sdui.impl.profile.components.suggestedForYouTopLevelSection","children":["$","$L4",null,{"componentKey":"com.linkedin.sdui.profile.card.refACoAACG3cA4BQD1WaaIemI6YTNJoCmfQrjOJD8ASuggestedForYou","children":["$","$L5","com.linkedin.sdui.profile.card.refACoAACG3cA4BQD1WaaIemI6YTNJoCmfQrjOJD8ASuggestedForYou",{"componentKey":"com.linkedin.sdui.profile.card.refACoAACG3cA4BQD1WaaIemI6YTNJoCmfQrjOJD8ASuggestedForYou","initialContent":"$undefined","componentkey":"com.linkedin.sdui.profile.card.refACoAACG3cA4BQD1WaaIemI6YTNJoCmfQrjOJD8ASuggestedForYou","renderWithoutWrapper":false}]}]}],["$","$L3",null,{"observabilityIdentifier":"com.linkedin.sdui.impl.profile.components.aboutSection","children":["$","$L4",null,{"componentKey":"com.linkedin.sdui.profile.card.refAbout","children":["$","$L5","com.linkedin.sdui.profile.card.refAbout",{"componentKey":"com.linkedin.sdui.profile.card.refAbout","initialContent":"$undefined","componentkey":"com.linkedin.sdui.profile.card.refAbout","renderWithoutWrapper":false}]}]}],["$","$L3",null,{"observabilityIdentifier":"com.linkedin.sdui.impl.profile.components.profileServicesSection","children":["$","$L4",null,{"componentKey":"com.linkedin.sdui.profile.card.refACoAACG3cA4BQD1WaaIemI6YTNJoCmfQrjOJD8AServices","children":["$","$L5","com.linkedin.sdui.profile.card.refACoAACG3cA4BQD1WaaIemI6YTNJoCmfQrjOJD8AServices",{"componentKey":"com.linkedin.sdui.profile.card.refACoAACG3cA4BQD1WaaIemI6YTNJoCmfQrjOJD8AServices","initialContent":"$undefined","componentkey":"com.linkedin.sdui.profile.card.refACoAACG3cA4BQD1WaaIemI6YTNJoCmfQrjOJD8AServices","renderWithoutWrapper":false}]}]}],["$","$L3",null,{"observabilityIdentifier":"com.linkedin.sdui.impl.profile.components.featuredSection","children":["$","$L4",null,{"componentKey":"com.linkedin.sdui.profile.card.refACoAACG3cA4BQD1WaaIemI6YTNJoCmfQrjOJD8AFeatured","children":["$","$L5","com.linkedin.sdui.profile.card.refACoAACG3cA4BQD1WaaIemI6YTNJoCmfQrjOJD8AFeatured",{"componentKey":"com.linkedin.sdui.profile.card.refACoAACG3cA4BQD1WaaIemI6YTNJoCmfQrjOJD8AFeatured","initialContent":"$undefined","componentkey":"com.linkedin.sdui.profile.card.refACoAACG3cA4BQD1WaaIemI6YTNJoCmfQrjOJD8AFeatured","renderWithoutWrapper":false}]}]}]]}]]]}]
# 2:null
